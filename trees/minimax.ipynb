# %% [markdown]
# # MiniMax search
# **Simple minimax on a tree.**

# %%
#import
from typing import List, Dict, Tuple

# %% [markdown]
# Creating a tree

# %%
tree: Dict[int, Tuple[List[int]]] = {
    1: (None, [2, 3]),
    2: (1, [4, 5]),
    3: (1, [6, 7]),
    4: (2, [8, 9]),
    5: (2, [10, 11]),
    6: (3, [12, 13]),
    7: (3, [14, 15]),
    8: (4, []),
    9: (4, []),
    10: (5, []),
    11: (5, []),
    12: (6, []),
    13: (6, []),
    14: (7, []),
    15: (7, [])
}

# %% [markdown]
# Minimax function
